# %% [markdown]
# # 2.a) Data Exploration
# Plot the histograms of variables 2-18 in the data (i.e., 17
# histograms total). Provide a brief discussion on your intuition regarding the variables and the
# resulting histogram

# %%
# Import libraries
import pandas as pd

# Load the data from the provided CSV file
file_path = 'data.csv'
data = pd.read_csv(file_path)

# Displaying data to understand the structure
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
# Checking for missing values in the dataset
missing_values = data.isnull().sum()
missing_values_percentage = (missing_values / len(data)) * 100

missing_values_summary = pd.DataFrame({
    'Missing Values': missing_values,
    'Percentage': missing_values_percentage
})

missing_values_summary[missing_values_summary['Missing Values'] > 0]

# Cleaning the missing values
# Removing rows with missing values in 'CREDIT_LIMIT' and 'MINIMUM_PAYMENTS'
data_cleaned = data.dropna(subset=['CREDIT_LIMIT', 'MINIMUM_PAYMENTS'])

# Verifying the removal of missing values
missing_values_cleaned = data_cleaned.isnull().sum()
missing_values_cleaned_summary = pd.DataFrame({
    'Missing Values After Cleaning': missing_values_cleaned
})

missing_values_cleaned_summary[missing_values_cleaned_summary['Missing Values After Cleaning'] > 0]
print(missing_values_cleaned_summary[missing_values_cleaned_summary['Missing Values After Cleaning'] > 0])
# Out:
# Empty DataFrame
# Columns: [Missing Values After Cleaning]
# Index: []

# %% [markdown]
# ## Data Visualization using Histograms

# %%
import matplotlib.pyplot as plt

data = data_cleaned
# Dropping the 'CUST_ID' column as it is not needed for the histograms
data_hist = data.drop(columns=['CUST_ID'])

# Plotting histograms for each variable
plt.figure(figsize=(20, 20))
for i, column in enumerate(data_hist.columns, 1):
    plt.subplot(5, 4, i)
    data_hist[column].hist(bins=20)
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# 1. **Balance:** A significant number of customers have low balances, suggesting either frequent usage or payment of their credit card bills.
# 2. **Balance Frequency:** Most customers seem to update their balance regularly, indicating active account management.
# 3. **Purchases:** A large portion of customers make relatively small purchases, with fewer customers making high-value purchases.
# 4. **One-Off Purchases:** Similar to the overall purchases, most one-off purchases are small, but there are customers who make substantial one-off purchases.
# 5. **Installments Purchases:** Many customers appear to prefer installment purchases, possibly for managing their cash flows or for large purchases.
# 6. **Cash Advance:** The majority of customers seem to use little to no cash advance feature, which could imply a preference for direct card purchases.
# 7. **Purchases Frequency:** There's a wide distribution in purchase frequency, with many customers making purchases quite frequently.
# 8. **One-Off Purchases Frequency:** A significant number of customers rarely make one-off purchases, whereas some do it quite frequently.
# 9. **Purchases Installments Frequency:** Many customers use installment options regularly, indicating a preference for spreading out payments.
# 10. **Cash Advance Frequency:** Most customers rarely take cash advances, aligning with the low usage of cash advance amounts.
# 11. **Cash Advance Transactions (Cash Advance TRX):** Corresponds with the cash advance amount, showing that most customers rarely engage in these transactions.
# 12. **Purchases Transactions (Purchases TRX):** There's a wide range in the number of purchase transactions, with many customers engaging in multiple transactions.
# 13. **Credit Limit:** The distribution of credit limits shows a range, with many customers having moderate to high credit limits.
# 14. **Payments:** Payment amounts vary widely among customers, reflecting differences in card usage, balance, and financial behavior.
# 15. **Minimum Payments:** The majority of customers have relatively low minimum payments, though there is variation.
# 16. **Percentage of Full Payment (PRC_FULL_PAYMENT):** Most customers do not pay their balance in full, which may indicate revolving credit behavior.
# 17. **Tenure:** Most customers have a long tenure with their credit cards, suggesting loyalty or satisfaction with the card services.

# %% [markdown]
# ## Visualizing Correlation between the Features
# Compute the Pearson’s correlation between all pairs of
# variables 2-18 (i.e., all variables except from the customer ID). Assign the resulting correla-
# tion values in a 17x17 matrix C, whose (i; j) element represents the correlation value between
# variables i and j, i.e., C(i; j) = corr(i; j). Visualize the resulting matrix C with a heatmap
# and discuss potential associations between the considered variables. Note: You can use the
# ‘heatmap’ function from ‘seaborn’

# %%
import seaborn as sns

# Calculating the Pearson's correlation matrix
correlation_matrix = data_hist.corr()

# Plotting the heatmap for the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Pearson's Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# ## Some key observations about the correlation plot:
#
# 1. **High Positive Correlation:** Variables with a strong positive correlation (close to 1) suggest a direct relationship where an increase in one is associated with an increase in the other. For example, PURCHASES and ONEOFF_PURCHASES may exhibit such a relationship.
#
# 2. **Negative Correlation:** A negative value (closer to -1) indicates an inverse relationship, where an increase in one variable correlates with a decrease in another.
#
# 3. **Low or No Correlation:** Values close to 0 imply little to no linear correlation between the variables.

# %%
# Identifying very high positive correlations
# let us define "very high" as a correlation coefficient greater than 0.75 (excluding 1)
high_corr_pairs = correlation_matrix.unstack().sort_values(ascending=False)
high_positive_correlations = high_corr_pairs[(high_corr_pairs > 0.75) & (high_corr_pairs < 1)]

high_positive_correlations
# Out:
# ONEOFF_PURCHASES                  PURCHASES                           0.916780
# PURCHASES                         ONEOFF_PURCHASES                    0.916780
# PURCHASES_FREQUENCY               PURCHASES_INSTALLMENTS_FREQUENCY    0.862338
# PURCHASES_INSTALLMENTS_FREQUENCY  PURCHASES_FREQUENCY                 0.862338
# CASH_ADVANCE_TRX                  CASH_ADVANCE_FREQUENCY              0.799593
# CASH_ADVANCE_FREQUENCY            CASH_ADVANCE_TRX                    0.799593
# dtype: float64

# %% [markdown]
# #### Table - High Positive Correlation Features
#  ----------------------
# | Variable 1                              | Variable 2                              | Correlation Coefficient |
# |-----------------------------------------|-----------------------------------------|-------------------------|
# | One-Off Purchases                       | Purchases                               | 0.92                    |
# | Purchases                               | One-Off Purchases                       | 0.92                    |
# | Purchases Frequency                     | Purchases Installments Frequency        | 0.86                    |
# | Purchases Installments Frequency        | Purchases Frequency                     | 0.86                    |
# | Cash Advance Transactions (CASH_ADVANCE_TRX) | Cash Advance Frequency            | 0.80                    |
# | Cash Advance Frequency                  | Cash Advance Transactions (CASH_ADVANCE_TRX) | 0.80                    |

# %% [markdown]
# # K-means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# Selecting the variables 2-16 for clustering
data_clustering = data.iloc[:, 1:17]

# Normalizing the data
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data_clustering)

# Using the elbow method to find the optimal number of clusters
inertia = []
K_range = range(1, 11)
for K in K_range:
    kmeans = KMeans(n_clusters=K, random_state=42)
    kmeans.fit(data_normalized)
    inertia.append(kmeans.inertia_)

# Plotting the elbow plot
plt.figure(figsize=(10, 6))
plt.plot(K_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.xticks(K_range)
plt.show()

# %%
from sklearn.metrics import silhouette_score

# Selecting variables 2-16 for clustering
data_clustering = data_cleaned.iloc[:, 1:17]

# Normalizing the data
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data_clustering)

# Calculating the silhouette score for each K
silhouette_scores = []
K_range = range(2, 11)  # Silhouette score is not defined for K=1
for K in K_range:
    kmeans = KMeans(n_clusters=K, random_state=42)
    cluster_labels = kmeans.fit_predict(data_normalized)
    silhouette_avg = silhouette_score(data_normalized, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plotting the silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(K_range, silhouette_scores, marker='o')
plt.title('Silhouette Score for Different Numbers of Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.xticks(K_range)
plt.show()

# Determine the optimal number of clusters as the one with the highest silhouette score
optimal_K = K_range[silhouette_scores.index(max(silhouette_scores))]
optimal_K, max(silhouette_scores)
# Out:
# (3, 0.2644986215353184)

# %%
# Importing necessary libraries since the code execution state was reset
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# KMeans with the optimal number of clusters determined to be 3
kmeans_optimal = KMeans(n_clusters=3, random_state=42)
kmeans_optimal.fit(data_normalized)

# Cluster labels
labels = kmeans_optimal.labels_

# Number of users in each cluster
clusters_counts = pd.Series(labels).value_counts().sort_index()

# Scatter (average distance) of each cluster
scatter = [np.mean(np.sqrt(np.sum((data_normalized[labels == i] - kmeans_optimal.cluster_centers_[i]) ** 2, axis=1))) for i in range(3)]

# Visualizing the number of users in each cluster
plt.figure(figsize=(8, 5))
sns.countplot(x=labels)
plt.title('Number of Users in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Users')
plt.xticks([0, 1, 2])
plt.show()

# Visualizing the scatter (average distance) for each cluster
plt.figure(figsize=(8, 5))
sns.barplot(x=np.arange(3), y=scatter)
plt.title('Scatter for Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Average Distance to Centroid')
plt.show()

# Since centroids are in a multidimensional array, converting it to a DataFrame for better visualization
centroids = scaler.inverse_transform(kmeans_optimal.cluster_centers_)
centroids_df = pd.DataFrame(centroids, columns=data_clustering.columns)

# # Generating markdown tables
# cluster_report_md = centroids_df.to_markdown(index=False)
# scatter_report_md = pd.DataFrame({
#     'Cluster': np.arange(3),
#     'Number of Users': clusters_counts.values,
#     'Scatter': scatter
# }).to_markdown(index=False)

# cluster_report_md, scatter_report_md

# %% [markdown]
# ## Centroids of Each Cluster:
# (Note: The values are the average features for each cluster)
# |   BALANCE |   BALANCE_FREQUENCY |   PURCHASES |   ONEOFF_PURCHASES |   INSTALLMENTS_PURCHASES |   CASH_ADVANCE |   PURCHASES_FREQUENCY |   ONEOFF_PURCHASES_FREQUENCY |   PURCHASES_INSTALLMENTS_FREQUENCY |   CASH_ADVANCE_FREQUENCY |   CASH_ADVANCE_TRX |   PURCHASES_TRX |   CREDIT_LIMIT |   PAYMENTS |   MINIMUM_PAYMENTS |   PRC_FULL_PAYMENT |
# |----------:|--------------------:|------------:|-------------------:|-------------------------:|---------------:|----------------------:|-----------------------------:|-----------------------------------:|-------------------------:|-------------------:|----------------:|---------------:|-----------:|-------------------:|-------------------:|
# |  4042.34  |            0.960847 |     390.18  |            248.38  |                  141.88  |       3900.49  |              0.235807 |                     0.110697 |                           0.148278 |                0.449045  |           12.5271  |         5.74356 |        6755.38 |   3085.94  |           1823.4   |          0.0336747 |
# |   828.684 |            0.859724 |     517.048 |            259.263 |                  258.119 |        336.569 |              0.470871 |                     0.135429 |                           0.348572 |                0.0706221 |            1.24523 |         8.83225 |        3264.87 |    946.707 |            534.878 |          0.163384  |
# |  2218.18  |            0.981838 |    4301.96  |           2736.02  |                 1566.44  |        458.588 |              0.950932 |                     0.669298 |                           0.749332 |                0.0633157 |            1.53878 |        56.9719  |        7753.38 |   4176.82  |           1232.19  |          0.300407  |

# %% [markdown]
# ## Cluster Summary
# Below is the scatter information for each cluster
# |   Cluster |   Number of Users |   Scatter |
# |----------:|------------------:|----------:|
# |         0 |              1555 |   3.36389 |
# |         1 |              5869 |   2.47384 |
# |         2 |              1212 |   4.20928 |

# %% [markdown]
# ## Cluster Analysis
#
# ### Cluster 0: High Credit and Cash Advance Users
# - **Balance**: High average balance.
# - **Purchases**: Lower average purchases, indicating these users may not be using their cards frequently for purchases.
# - **Cash Advance**: Very high average cash advance, suggesting a preference or need for cash over direct card purchases.
# - **Purchases Frequency**: Low, aligning with the lower purchases amount.
# - **Credit Limit**: High, which may enable the high cash advance behavior.
# - **Payments**: High, which may reflect the need to cover higher balances due to cash advances.
# - **Minimum Payments**: Highest among clusters, potentially due to the higher balances.
# - **Full Payment Percentage**: Lowest, which may suggest these users carry a balance more often.
#
# ### Cluster 1: Lower Balance and Active Users
# - **Balance**: Lowest average balance.
# - **Purchases**: Moderate, indicating regular use of the credit card for purchases.
# - **Cash Advance**: Low, suggesting these users prefer to use their card for purchases rather than cash advances.
# - **Purchases Frequency**: Moderately high, again indicating regular use.
# - **Credit Limit**: Moderate, in line with their purchasing behavior.
# - **Payments**: Lowest, which might be due to lower balances and purchases.
# - **Minimum Payments**: Low, aligning with the lower overall credit use.
# - **Full Payment Percentage**: Moderate, suggesting a fair number of users in this cluster pay off their balances.
#
# ### Cluster 2: High Spenders with Highest Purchase Frequency
# - **Balance**: Moderate.
# - **Purchases**: Very high, indicating these users utilize their cards primarily for making purchases.
# - **Cash Advance**: Lowest, which is consistent with a preference for making purchases.
# - **Purchases Frequency**: Very high, the highest among all clusters, showing these users are very active in using their cards.
# - **Credit Limit**: Highest, which supports higher spending behavior.
# - **Payments**: Highest, reflecting the need to cover high purchasing activity.
# - **Minimum Payments**: Moderate, potentially due to high purchase volumes.
# - **Full Payment Percentage**: Highest, indicating a good number of these users may pay off their balance, aligning with responsible credit card usage and potentially higher financial liquidity.
#
# ### Cluster Sizes and Scatter:
# - Cluster 1 is the largest, suggesting that most users fall into the lower balance and active user category.
# - Cluster 0 is the smallest, which might indicate fewer users engage in high cash advances.
# - Scatter values are highest for Cluster 2, indicating users in this cluster are more spread out in terms of their credit card usage patterns. This could be due to variability in how much and how often they make purchases.
#
# Overall, the clustering suggests distinct user behaviors, from those who primarily use their cards for cash advances, those who use their cards regularly but with lower balances and purchases, to those who are high spenders with high purchase frequencies. These insights could be very valuable for personalized marketing strategies, risk assessment, and customer service enhancements.

# %% [markdown]
# ## Finding optimal K using different feature combinations
# Repeat question (c) using a different combination of
# features at the input of K-Means, informed by your findings in questions (a) and (b). Please
# discuss your findings. Note: Consider removing highly skewed features and/or keeping features
# that are not correlated with each other.

# %%
# Selected features based on correlation analysis
selected_features = ['PURCHASES', 'PURCHASES_FREQUENCY', 'CASH_ADVANCE_TRX']

# Extract the selected features
data_selected = data_cleaned[selected_features]

# Scale the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_selected)

# Determine the optimal number of clusters using the elbow method
inertia = []
silhouette_scores = []
K_range = range(2, 11)
for K in K_range:
    kmeans = KMeans(n_clusters=K, random_state=42)
    kmeans.fit(data_scaled)
    inertia.append(kmeans.inertia_)
    silhouette_avg = silhouette_score(data_scaled, kmeans.labels_)
    silhouette_scores.append(silhouette_avg)

# Plot the elbow plot
plt.figure(figsize=(10, 6))
plt.plot(K_range, inertia, marker='o')
plt.title('Elbow Method For Optimal k')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.xticks(K_range)
plt.show()

# Plot the silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(K_range, silhouette_scores, marker='o')
plt.title('Silhouette Score for Different Numbers of Clusters')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.xticks(K_range)
plt.show()

# Fit K-Means with the optimal number of clusters determined from the elbow method and silhouette scores
optimal_K = K_range[inertia.index(min(inertia))] # Replace this with the chosen K based on your elbow plot analysis
kmeans_optimal = KMeans(n_clusters=optimal_K, random_state=42)
kmeans_optimal.fit(data_scaled)

# Analyze the clusters
cluster_labels = kmeans_optimal.labels_
centroids = kmeans_optimal.cluster_centers_

# %%
from sklearn.mixture import GaussianMixture

# Since the optimal number of clusters K* is 4 from the previous K-Means analysis
# We'll use this to set the number of components for GMM
gmm = GaussianMixture(n_components=4, random_state=42)

# Fit the GMM model
gmm.fit(data_selected)

# The mean vector for each Gaussian
means = gmm.means_

# The covariance matrix for each Gaussian
covariances = gmm.covariances_

# Compute the log-likelihood of each sample
log_likelihood = gmm.score_samples(data_selected)

# Plot the histogram of the resulting log-likelihood values
plt.figure(figsize=(8, 5))
plt.hist(log_likelihood, bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of Log-Likelihood Values')
plt.xlabel('Log-Likelihood')
plt.ylabel('Frequency')
plt.show()

# Creating a DataFrame for mean vectors for better visualization
means_df = pd.DataFrame(means, columns=selected_features)
means_df.index.name = 'Gaussian Component'
means_df.reset_index(inplace=True)

# Display the mean vectors in a more structured format
means_df
# Out:
#    Gaussian Component    PURCHASES  PURCHASES_FREQUENCY  CASH_ADVANCE_TRX
# 0                   0     0.000000             0.000000          6.253409
# 1                   1   867.557371             0.479311          8.482561
# 2                   2  4514.937495             0.954430          2.199713
# 3                   3  1084.447257             0.666467          0.000000

# %%
covariances = gmm.covariances_
covariance_dfs = [pd.DataFrame(cov, columns=[selected_features], index=[selected_features]) for cov in covariances]
# Set display options to show more rows/columns
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 10)
for i, cov_dfs in enumerate(covariance_dfs):
    print(f"Covariance Report for cluster {i}")
    print(cov_dfs)
# Out:
# Covariance Report for cluster 0
#                     PURCHASES PURCHASES_FREQUENCY CASH_ADVANCE_TRX
# PURCHASES            0.000001            0.000000         0.000000
# PURCHASES_FREQUENCY  0.000000            0.000001         0.000000
# CASH_ADVANCE_TRX     0.000000            0.000000        51.250059
# Covariance Report for cluster 1
#                         PURCHASES PURCHASES_FREQUENCY CASH_ADVANCE_TRX
# PURCHASES            1.499898e+06          170.022826      2158.244849
# PURCHASES_FREQUENCY  1.700228e+02            0.102277         0.417365
# CASH_ADVANCE_TRX     2.158245e+03            0.417365       111.059725
# Covariance Report for cluster 2
#                         PURCHASES PURCHASES_FREQUENCY CASH_ADVANCE_TRX
# PURCHASES            3.755837e+07          -73.291779     -4181.983694
# PURCHASES_FREQUENCY -7.329178e+01            0.010173         0.015517
# CASH_ADVANCE_TRX    -4.181984e+03            0.015517         4.013094
# Covariance Report for cluster 3
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming `covariances` is your array of covariance matrices
for i, cov in enumerate(covariances):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cov, annot=True, fmt=".2f")
    plt.title(f'Heatmap of Covariance Matrix for Gaussian {i+1}')
    plt.show()
